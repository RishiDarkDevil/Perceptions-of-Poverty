# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# ## Partial Profile Discrete Choice Experiment

# %% [markdown]
# We dropped $Bank\enspace Account$ primarily because:
# - We had PPDCE for $11$ attributes, each of which are $2$ level.
# - We found $Maternal\enspace Health$ and $Bank\enspace Account$ are dropped from the new MPI model.
# - We saw $Bank\enspace Account$ has lower contribution in West Bengal.

# %%
poverty_indicators = 'Nutrition, Years of Schooling, Cooking Fuel, Housing, Sanitation, Maternal Health, School Attendance, Assets, Drinking Water, Electricity, Child & Adolescent Mortality'.split(', ')

# %%
poverty_indicators
# Out:
# ['Nutrition',
#  'Years of Schooling',
#  'Cooking Fuel',
#  'Housing',
#  'Sanitation',
#  'Maternal Health',
#  'School Attendance',
#  'Assets',
#  'Drinking Water',
#  'Electricity',
#  'Child & Adolescent Mortality']

# %%
len(poverty_indicators)
# Out:
# 11

# %%
map_label_to_emojis = {
  '1': '✅',
  '2': '❌',
  '0': ''
}

# %%
design = pd.read_csv(
  'partial-profile-DCE.txt',
  sep=' ',
  names = ['Pair', *[x+'1' for x in poverty_indicators], *[x+'2' for x in poverty_indicators]],
  header = 0
)

# %%
minus_1 = [[x if x != '-1' else '2' for x in row] for row in design.to_numpy()[:,1:]][0][2]

# %%
minus_1
# Out:
# '−1'

# %%
arr = np.array([[x if x != minus_1 else '2' for x in row] for row in design.to_numpy()])

# %%
arr
# Out:
# array([['1', '1', '1', ..., '0', '0', '0'],
#        ['2', '1', '2', ..., '0', '0', '0'],
#        ['3', '1', '1', ..., '0', '0', '0'],
#        ...,
#        ['118', '0', '0', ..., '1', '1', '2'],
#        ['119', '0', '0', ..., '2', '1', '1'],
#        ['120', '0', '0', ..., '1', '1', '1']], dtype='<U21')

# %%
first_pair = pd.DataFrame(np.vectorize(map_label_to_emojis.get)(arr[:,1:12]))

# %%
second_pair = pd.DataFrame(np.vectorize(map_label_to_emojis.get)(arr[:,12:]))

# %%
first_pair.columns = poverty_indicators
second_pair.columns = poverty_indicators

# %%
first_pair
# Out:
#     Nutrition Years of Schooling Cooking Fuel Housing Sanitation  \
# 0           ✅                  ✅            ❌       ❌
# 1           ✅                  ❌            ❌       ❌
# 2           ✅                  ✅            ❌       ✅
# 3           ✅                  ❌            ❌       ✅
# 4           ✅                  ✅            ✅       ❌
# ..        ...                ...          ...     ...        ...
# 115
# 116
# 117
# 118
# 119
#
#     Maternal Health School Attendance Assets Drinking Water Electricity  \
# 0
# 1
# 2
# 3
# 4
# ..              ...               ...    ...            ...         ...
# 115                                 ✅                     ❌           ❌
# 116                                 ✅                     ✅           ✅
# 117                                 ✅                     ❌           ✅
# 118                                 ✅                     ✅           ✅
# 119                                 ✅                     ❌           ✅
#
#     Child & Adolescent Mortality
# 0
# 1
# 2
# 3
# 4
# ..                           ...
# 115                            ✅
# 116                            ❌
# 117                            ❌
# 118                            ✅
# 119                            ✅
#
# [120 rows x 11 columns]

# %%
second_pair
# Out:
#     Nutrition Years of Schooling Cooking Fuel Housing Sanitation  \
# 0           ❌                  ❌            ❌       ❌
# 1           ❌                  ✅            ❌       ❌
# 2           ❌                  ❌            ❌       ✅
# 3           ❌                  ✅            ❌       ✅
# 4           ❌                  ❌            ✅       ❌
# ..        ...                ...          ...     ...        ...
# 115
# 116
# 117
# 118
# 119
#
#     Maternal Health School Attendance Assets Drinking Water Electricity  \
# 0
# 1
# 2
# 3
# 4
# ..              ...               ...    ...            ...         ...
# 115                                 ❌                     ✅           ❌
# 116                                 ❌                     ❌           ✅
# 117                                 ❌                     ✅           ✅
# 118                                 ❌                     ❌           ✅
# 119                                 ❌                     ✅           ✅
#
#     Child & Adolescent Mortality
# 0
# 1
# 2
# 3
# 4
# ..                           ...
# 115                            ✅
# 116                            ❌
# 117                            ❌
# 118                            ✅
# 119                            ✅
#
# [120 rows x 11 columns]

# %%
first_pair.to_csv('first-pair.csv')
second_pair.to_csv('second-pair.csv')

# %%
first_pair.to_numpy()
# Out:
# array([['✅', '✅', '❌', ..., '', '', ''],
#        ['✅', '❌', '❌', ..., '', '', ''],
#        ['✅', '✅', '❌', ..., '', '', ''],
#        ...,
#        ['', '', '', ..., '❌', '✅', '❌'],
#        ['', '', '', ..., '✅', '✅', '✅'],
#        ['', '', '', ..., '❌', '✅', '✅']], dtype=object)

# %%
second_pair.to_numpy()
# Out:
# array([['❌', '❌', '❌', ..., '', '', ''],
#        ['❌', '✅', '❌', ..., '', '', ''],
#        ['❌', '❌', '❌', ..., '', '', ''],
#        ...,
#        ['', '', '', ..., '✅', '✅', '❌'],
#        ['', '', '', ..., '❌', '✅', '✅'],
#        ['', '', '', ..., '✅', '✅', '✅']], dtype=object)

# %%
N24_fp = first_pair.to_numpy()[1::2]
N24_sp = second_pair.to_numpy()[1::2]

# %%
N24_fp
# Out:
# array([['✅', '❌', '❌', '❌', '', '', '', '', '', '', ''],
#        ['✅', '❌', '❌', '✅', '', '', '', '', '', '', ''],
#        ['✅', '❌', '✅', '❌', '', '', '', '', '', '', ''],
#        ['✅', '❌', '✅', '✅', '', '', '', '', '', '', ''],
#        ['✅', '❌', '', '', '❌', '❌', '', '', '', '', ''],
#        ['✅', '❌', '', '', '❌', '✅', '', '', '', '', ''],
#        ['✅', '✅', '', '', '❌', '❌', '', '', '', '', ''],
#        ['✅', '✅', '', '', '❌', '✅', '', '', '', '', ''],
#        ['❌', '', '', '', '✅', '', '❌', '❌', '', '', ''],
#        ['❌', '', '', '', '✅', '', '❌', '✅', '', '', ''],
#        ['✅', '', '', '', '✅', '', '❌', '❌', '', '', ''],
#        ['✅', '', '', '', '✅', '', '❌', '✅', '', '', ''],
#        ['❌', '❌', '', '', '', '', '', '✅', '❌', '', ''],
#        ['❌', '✅', '', '', '', '', '', '✅', '❌', '', ''],
#        ['✅', '❌', '', '', '', '', '', '✅', '❌', '', ''],
#        ['✅', '✅', '', '', '', '', '', '✅', '❌', '', ''],
#        ['✅', '❌', '', '', '', '', '', '', '', '❌', '❌'],
#        ['✅', '❌', '', '', '', '', '', '', '', '❌', '✅'],
#        ['✅', '❌', '', '', '', '', '', '', '', '✅', '❌'],
#        ['✅', '❌', '', '', '', '', '', '', '', '✅', '✅'],
#        ['', '✅', '', '', '', '❌', '❌', '', '❌', '', ''],
#        ['', '✅', '', '', '', '❌', '✅', '', '❌', '', ''],
#        ['', '✅', '', '', '', '✅', '❌', '', '❌', '', ''],
#        ['', '✅', '', '', '', '✅', '✅', '', '❌', '', ''],
#        ['', '', '✅', '❌', '❌', '❌', '', '', '', '', ''],
#        ['', '', '✅', '❌', '❌', '✅', '', '', '', '', ''],
#        ['', '', '✅', '❌', '✅', '❌', '', '', '', '', ''],
#        ['', '', '✅', '❌', '✅', '✅', '', '', '', '', ''],
#        ['', '', '✅', '❌', '', '', '❌', '', '', '❌', ''],
#        ['', '', '✅', '❌', '', '', '✅', '', '', '❌', ''],
#        ['', '', '✅', '✅', '', '', '❌', '', '', '❌', ''],
#        ['', '', '✅', '✅', '', '', '✅', '', '', '❌', ''],
#        ['', '', '✅', '', '', '', '', '❌', '❌', '❌', ''],
#        ['', '', '✅', '', '', '', '', '❌', '✅', '❌', ''],
#        ['', '', '✅', '', '', '', '', '✅', '❌', '❌', ''],
#        ['', '', '✅', '', '', '', '', '✅', '✅', '❌', ''],
#        ['', '', '❌', '', '❌', '', '', '', '', '✅', '❌'],
#        ['', '', '❌', '', '✅', '', '', '', '', '✅', '❌'],
#        ['', '', '✅', '', '❌', '', '', '', '', '✅', '❌'],
#        ['', '', '✅', '', '✅', '', '', '', '', '✅', '❌'],
#        ['', '', '', '✅', '', '❌', '', '❌', '', '', '❌'],
#        ['', '', '', '✅', '', '❌', '', '❌', '', '', '✅'],
#        ['', '', '', '✅', '', '❌', '', '✅', '', '', '❌'],
#        ['', '', '', '✅', '', '❌', '', '✅', '', '', '✅'],
#        ['', '', '', '✅', '❌', '', '❌', '', '❌', '', ''],
#        ['', '', '', '✅', '❌', '', '❌', '', '✅', '', ''],
#        ['', '', '', '✅', '❌', '', '✅', '', '❌', '', ''],
#        ['', '', '', '✅', '❌', '', '✅', '', '✅', '', ''],
#        ['', '', '', '', '', '✅', '❌', '', '', '❌', '❌'],
#        ['', '', '', '', '', '✅', '❌', '', '', '✅', '❌'],
#        ['', '', '', '', '', '✅', '✅', '', '', '❌', '❌'],
#        ['', '', '', '', '', '✅', '✅', '', '', '✅', '❌'],
#        ['', '', '', '', '', '✅', '', '❌', '❌', '', '❌'],
#        ['', '', '', '', '', '✅', '', '❌', '❌', '', '✅'],
#        ['', '', '', '', '', '✅', '', '❌', '✅', '', '❌'],
#        ['', '', '', '', '', '✅', '', '❌', '✅', '', '✅'],
#        ['', '', '', '', '', '', '✅', '', '❌', '❌', '❌'],
#        ['', '', '', '', '', '', '✅', '', '❌', '❌', '✅'],
#        ['', '', '', '', '', '', '✅', '', '❌', '✅', '❌'],
#        ['', '', '', '', '', '', '✅', '', '❌', '✅', '✅']], dtype=object)

# %%
N24_sp
# Out:
# array([['❌', '✅', '❌', '❌', '', '', '', '', '', '', ''],
#        ['❌', '✅', '❌', '✅', '', '', '', '', '', '', ''],
#        ['❌', '✅', '✅', '❌', '', '', '', '', '', '', ''],
#        ['❌', '✅', '✅', '✅', '', '', '', '', '', '', ''],
#        ['❌', '❌', '', '', '✅', '❌', '', '', '', '', ''],
#        ['❌', '❌', '', '', '✅', '✅', '', '', '', '', ''],
#        ['❌', '✅', '', '', '✅', '❌', '', '', '', '', ''],
#        ['❌', '✅', '', '', '✅', '✅', '', '', '', '', ''],
#        ['❌', '', '', '', '❌', '', '✅', '❌', '', '', ''],
#        ['❌', '', '', '', '❌', '', '✅', '✅', '', '', ''],
#        ['✅', '', '', '', '❌', '', '✅', '❌', '', '', ''],
#        ['✅', '', '', '', '❌', '', '✅', '✅', '', '', ''],
#        ['❌', '❌', '', '', '', '', '', '❌', '✅', '', ''],
#        ['❌', '✅', '', '', '', '', '', '❌', '✅', '', ''],
#        ['✅', '❌', '', '', '', '', '', '❌', '✅', '', ''],
#        ['✅', '✅', '', '', '', '', '', '❌', '✅', '', ''],
#        ['❌', '✅', '', '', '', '', '', '', '', '❌', '❌'],
#        ['❌', '✅', '', '', '', '', '', '', '', '❌', '✅'],
#        ['❌', '✅', '', '', '', '', '', '', '', '✅', '❌'],
#        ['❌', '✅', '', '', '', '', '', '', '', '✅', '✅'],
#        ['', '❌', '', '', '', '❌', '❌', '', '✅', '', ''],
#        ['', '❌', '', '', '', '❌', '✅', '', '✅', '', ''],
#        ['', '❌', '', '', '', '✅', '❌', '', '✅', '', ''],
#        ['', '❌', '', '', '', '✅', '✅', '', '✅', '', ''],
#        ['', '', '❌', '✅', '❌', '❌', '', '', '', '', ''],
#        ['', '', '❌', '✅', '❌', '✅', '', '', '', '', ''],
#        ['', '', '❌', '✅', '✅', '❌', '', '', '', '', ''],
#        ['', '', '❌', '✅', '✅', '✅', '', '', '', '', ''],
#        ['', '', '❌', '❌', '', '', '❌', '', '', '✅', ''],
#        ['', '', '❌', '❌', '', '', '✅', '', '', '✅', ''],
#        ['', '', '❌', '✅', '', '', '❌', '', '', '✅', ''],
#        ['', '', '❌', '✅', '', '', '✅', '', '', '✅', ''],
#        ['', '', '❌', '', '', '', '', '❌', '❌', '✅', ''],
#        ['', '', '❌', '', '', '', '', '❌', '✅', '✅', ''],
#        ['', '', '❌', '', '', '', '', '✅', '❌', '✅', ''],
#        ['', '', '❌', '', '', '', '', '✅', '✅', '✅', ''],
#        ['', '', '❌', '', '❌', '', '', '', '', '❌', '✅'],
#        ['', '', '❌', '', '✅', '', '', '', '', '❌', '✅'],
#        ['', '', '✅', '', '❌', '', '', '', '', '❌', '✅'],
#        ['', '', '✅', '', '✅', '', '', '', '', '❌', '✅'],
#        ['', '', '', '❌', '', '✅', '', '❌', '', '', '❌'],
#        ['', '', '', '❌', '', '✅', '', '❌', '', '', '✅'],
#        ['', '', '', '❌', '', '✅', '', '✅', '', '', '❌'],
#        ['', '', '', '❌', '', '✅', '', '✅', '', '', '✅'],
#        ['', '', '', '❌', '✅', '', '❌', '', '❌', '', ''],
#        ['', '', '', '❌', '✅', '', '❌', '', '✅', '', ''],
#        ['', '', '', '❌', '✅', '', '✅', '', '❌', '', ''],
#        ['', '', '', '❌', '✅', '', '✅', '', '✅', '', ''],
#        ['', '', '', '', '', '❌', '❌', '', '', '❌', '✅'],
#        ['', '', '', '', '', '❌', '❌', '', '', '✅', '✅'],
#        ['', '', '', '', '', '❌', '✅', '', '', '❌', '✅'],
#        ['', '', '', '', '', '❌', '✅', '', '', '✅', '✅'],
#        ['', '', '', '', '', '❌', '', '✅', '❌', '', '❌'],
#        ['', '', '', '', '', '❌', '', '✅', '❌', '', '✅'],
#        ['', '', '', '', '', '❌', '', '✅', '✅', '', '❌'],
#        ['', '', '', '', '', '❌', '', '✅', '✅', '', '✅'],
#        ['', '', '', '', '', '', '❌', '', '✅', '❌', '❌'],
#        ['', '', '', '', '', '', '❌', '', '✅', '❌', '✅'],
#        ['', '', '', '', '', '', '❌', '', '✅', '✅', '❌'],
#        ['', '', '', '', '', '', '❌', '', '✅', '✅', '✅']], dtype=object)

# %%
N24_fp = [[x for x in row] for row in N24_fp]
N24_sp = [[x for x in row] for row in N24_sp]

# %%
N24_fp = [list(zip(row, poverty_indicators)) for row in N24_fp]
N24_sp = [list(zip(row, poverty_indicators)) for row in N24_sp]

# %%
N24_fp
# Out:
# [[('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('❌', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('❌', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('❌', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('❌', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('❌', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('❌', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('✅', 'Nutrition'),
#   ('❌', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('✅', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('❌', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('✅', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('✅', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('❌', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('❌', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('✅', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('✅', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('', 'Sanitation'),
#   ('❌', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('✅', 'Assets'),
#   ('', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('✅', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('✅', 'Housing'),
#   ('❌', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('✅', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('❌', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('✅', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('✅', 'Maternal Health'),
#   ('', 'School Attendance'),
#   ('❌', 'Assets'),
#   ('✅', 'Drinking Water'),
#   ('', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('❌', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('❌', 'Child & Adolescent Mortality')],
#  [('', 'Nutrition'),
#   ('', 'Years of Schooling'),
#   ('', 'Cooking Fuel'),
#   ('', 'Housing'),
#   ('', 'Sanitation'),
#   ('', 'Maternal Health'),
#   ('✅', 'School Attendance'),
#   ('', 'Assets'),
#   ('❌', 'Drinking Water'),
#   ('✅', 'Electricity'),
#   ('✅', 'Child & Adolescent Mortality')]]

# %%
N24_fp = [[' '.join(tup) for tup in row if tup[0] != ''] for row in N24_fp]
N24_sp = [[' '.join(tup) for tup in row if tup[0] != ''] for row in N24_sp]

# %%
N24_fp
# Out:
# [['✅ Nutrition', '❌ Years of Schooling', '❌ Cooking Fuel', '❌ Housing'],
#  ['✅ Nutrition', '❌ Years of Schooling', '❌ Cooking Fuel', '✅ Housing'],
#  ['✅ Nutrition', '❌ Years of Schooling', '✅ Cooking Fuel', '❌ Housing'],
#  ['✅ Nutrition', '❌ Years of Schooling', '✅ Cooking Fuel', '✅ Housing'],
#  ['✅ Nutrition', '❌ Years of Schooling', '❌ Sanitation', '❌ Maternal Health'],
#  ['✅ Nutrition', '❌ Years of Schooling', '❌ Sanitation', '✅ Maternal Health'],
#  ['✅ Nutrition', '✅ Years of Schooling', '❌ Sanitation', '❌ Maternal Health'],
#  ['✅ Nutrition', '✅ Years of Schooling', '❌ Sanitation', '✅ Maternal Health'],
#  ['❌ Nutrition', '✅ Sanitation', '❌ School Attendance', '❌ Assets'],
#  ['❌ Nutrition', '✅ Sanitation', '❌ School Attendance', '✅ Assets'],
#  ['✅ Nutrition', '✅ Sanitation', '❌ School Attendance', '❌ Assets'],
#  ['✅ Nutrition', '✅ Sanitation', '❌ School Attendance', '✅ Assets'],
#  ['❌ Nutrition', '❌ Years of Schooling', '✅ Assets', '❌ Drinking Water'],
#  ['❌ Nutrition', '✅ Years of Schooling', '✅ Assets', '❌ Drinking Water'],
#  ['✅ Nutrition', '❌ Years of Schooling', '✅ Assets', '❌ Drinking Water'],
#  ['✅ Nutrition', '✅ Years of Schooling', '✅ Assets', '❌ Drinking Water'],
#  ['✅ Nutrition',
#   '❌ Years of Schooling',
#   '❌ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Nutrition',
#   '❌ Years of Schooling',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ Nutrition',
#   '❌ Years of Schooling',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Nutrition',
#   '❌ Years of Schooling',
#   '✅ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ Years of Schooling',
#   '❌ Maternal Health',
#   '❌ School Attendance',
#   '❌ Drinking Water'],
#  ['✅ Years of Schooling',
#   '❌ Maternal Health',
#   '✅ School Attendance',
#   '❌ Drinking Water'],
#  ['✅ Years of Schooling',
#   '✅ Maternal Health',
#   '❌ School Attendance',
#   '❌ Drinking Water'],
#  ['✅ Years of Schooling',
#   '✅ Maternal Health',
#   '✅ School Attendance',
#   '❌ Drinking Water'],
#  ['✅ Cooking Fuel', '❌ Housing', '❌ Sanitation', '❌ Maternal Health'],
#  ['✅ Cooking Fuel', '❌ Housing', '❌ Sanitation', '✅ Maternal Health'],
#  ['✅ Cooking Fuel', '❌ Housing', '✅ Sanitation', '❌ Maternal Health'],
#  ['✅ Cooking Fuel', '❌ Housing', '✅ Sanitation', '✅ Maternal Health'],
#  ['✅ Cooking Fuel', '❌ Housing', '❌ School Attendance', '❌ Electricity'],
#  ['✅ Cooking Fuel', '❌ Housing', '✅ School Attendance', '❌ Electricity'],
#  ['✅ Cooking Fuel', '✅ Housing', '❌ School Attendance', '❌ Electricity'],
#  ['✅ Cooking Fuel', '✅ Housing', '✅ School Attendance', '❌ Electricity'],
#  ['✅ Cooking Fuel', '❌ Assets', '❌ Drinking Water', '❌ Electricity'],
#  ['✅ Cooking Fuel', '❌ Assets', '✅ Drinking Water', '❌ Electricity'],
#  ['✅ Cooking Fuel', '✅ Assets', '❌ Drinking Water', '❌ Electricity'],
#  ['✅ Cooking Fuel', '✅ Assets', '✅ Drinking Water', '❌ Electricity'],
#  ['❌ Cooking Fuel',
#   '❌ Sanitation',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ Cooking Fuel',
#   '✅ Sanitation',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Cooking Fuel',
#   '❌ Sanitation',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Cooking Fuel',
#   '✅ Sanitation',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Housing',
#   '❌ Maternal Health',
#   '❌ Assets',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Housing',
#   '❌ Maternal Health',
#   '❌ Assets',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ Housing',
#   '❌ Maternal Health',
#   '✅ Assets',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Housing',
#   '❌ Maternal Health',
#   '✅ Assets',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ Housing', '❌ Sanitation', '❌ School Attendance', '❌ Drinking Water'],
#  ['✅ Housing', '❌ Sanitation', '❌ School Attendance', '✅ Drinking Water'],
#  ['✅ Housing', '❌ Sanitation', '✅ School Attendance', '❌ Drinking Water'],
#  ['✅ Housing', '❌ Sanitation', '✅ School Attendance', '✅ Drinking Water'],
#  ['✅ Maternal Health',
#   '❌ School Attendance',
#   '❌ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Maternal Health',
#   '❌ School Attendance',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Maternal Health',
#   '✅ School Attendance',
#   '❌ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Maternal Health',
#   '✅ School Attendance',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Maternal Health',
#   '❌ Assets',
#   '❌ Drinking Water',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Maternal Health',
#   '❌ Assets',
#   '❌ Drinking Water',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ Maternal Health',
#   '❌ Assets',
#   '✅ Drinking Water',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ Maternal Health',
#   '❌ Assets',
#   '✅ Drinking Water',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ School Attendance',
#   '❌ Drinking Water',
#   '❌ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ School Attendance',
#   '❌ Drinking Water',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ School Attendance',
#   '❌ Drinking Water',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['✅ School Attendance',
#   '❌ Drinking Water',
#   '✅ Electricity',
#   '✅ Child & Adolescent Mortality']]

# %%
N24_sp
# Out:
# [['❌ Nutrition', '✅ Years of Schooling', '❌ Cooking Fuel', '❌ Housing'],
#  ['❌ Nutrition', '✅ Years of Schooling', '❌ Cooking Fuel', '✅ Housing'],
#  ['❌ Nutrition', '✅ Years of Schooling', '✅ Cooking Fuel', '❌ Housing'],
#  ['❌ Nutrition', '✅ Years of Schooling', '✅ Cooking Fuel', '✅ Housing'],
#  ['❌ Nutrition', '❌ Years of Schooling', '✅ Sanitation', '❌ Maternal Health'],
#  ['❌ Nutrition', '❌ Years of Schooling', '✅ Sanitation', '✅ Maternal Health'],
#  ['❌ Nutrition', '✅ Years of Schooling', '✅ Sanitation', '❌ Maternal Health'],
#  ['❌ Nutrition', '✅ Years of Schooling', '✅ Sanitation', '✅ Maternal Health'],
#  ['❌ Nutrition', '❌ Sanitation', '✅ School Attendance', '❌ Assets'],
#  ['❌ Nutrition', '❌ Sanitation', '✅ School Attendance', '✅ Assets'],
#  ['✅ Nutrition', '❌ Sanitation', '✅ School Attendance', '❌ Assets'],
#  ['✅ Nutrition', '❌ Sanitation', '✅ School Attendance', '✅ Assets'],
#  ['❌ Nutrition', '❌ Years of Schooling', '❌ Assets', '✅ Drinking Water'],
#  ['❌ Nutrition', '✅ Years of Schooling', '❌ Assets', '✅ Drinking Water'],
#  ['✅ Nutrition', '❌ Years of Schooling', '❌ Assets', '✅ Drinking Water'],
#  ['✅ Nutrition', '✅ Years of Schooling', '❌ Assets', '✅ Drinking Water'],
#  ['❌ Nutrition',
#   '✅ Years of Schooling',
#   '❌ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ Nutrition',
#   '✅ Years of Schooling',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Nutrition',
#   '✅ Years of Schooling',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ Nutrition',
#   '✅ Years of Schooling',
#   '✅ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Years of Schooling',
#   '❌ Maternal Health',
#   '❌ School Attendance',
#   '✅ Drinking Water'],
#  ['❌ Years of Schooling',
#   '❌ Maternal Health',
#   '✅ School Attendance',
#   '✅ Drinking Water'],
#  ['❌ Years of Schooling',
#   '✅ Maternal Health',
#   '❌ School Attendance',
#   '✅ Drinking Water'],
#  ['❌ Years of Schooling',
#   '✅ Maternal Health',
#   '✅ School Attendance',
#   '✅ Drinking Water'],
#  ['❌ Cooking Fuel', '✅ Housing', '❌ Sanitation', '❌ Maternal Health'],
#  ['❌ Cooking Fuel', '✅ Housing', '❌ Sanitation', '✅ Maternal Health'],
#  ['❌ Cooking Fuel', '✅ Housing', '✅ Sanitation', '❌ Maternal Health'],
#  ['❌ Cooking Fuel', '✅ Housing', '✅ Sanitation', '✅ Maternal Health'],
#  ['❌ Cooking Fuel', '❌ Housing', '❌ School Attendance', '✅ Electricity'],
#  ['❌ Cooking Fuel', '❌ Housing', '✅ School Attendance', '✅ Electricity'],
#  ['❌ Cooking Fuel', '✅ Housing', '❌ School Attendance', '✅ Electricity'],
#  ['❌ Cooking Fuel', '✅ Housing', '✅ School Attendance', '✅ Electricity'],
#  ['❌ Cooking Fuel', '❌ Assets', '❌ Drinking Water', '✅ Electricity'],
#  ['❌ Cooking Fuel', '❌ Assets', '✅ Drinking Water', '✅ Electricity'],
#  ['❌ Cooking Fuel', '✅ Assets', '❌ Drinking Water', '✅ Electricity'],
#  ['❌ Cooking Fuel', '✅ Assets', '✅ Drinking Water', '✅ Electricity'],
#  ['❌ Cooking Fuel',
#   '❌ Sanitation',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Cooking Fuel',
#   '✅ Sanitation',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ Cooking Fuel',
#   '❌ Sanitation',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['✅ Cooking Fuel',
#   '✅ Sanitation',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Housing',
#   '✅ Maternal Health',
#   '❌ Assets',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ Housing',
#   '✅ Maternal Health',
#   '❌ Assets',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Housing',
#   '✅ Maternal Health',
#   '✅ Assets',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ Housing',
#   '✅ Maternal Health',
#   '✅ Assets',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Housing', '✅ Sanitation', '❌ School Attendance', '❌ Drinking Water'],
#  ['❌ Housing', '✅ Sanitation', '❌ School Attendance', '✅ Drinking Water'],
#  ['❌ Housing', '✅ Sanitation', '✅ School Attendance', '❌ Drinking Water'],
#  ['❌ Housing', '✅ Sanitation', '✅ School Attendance', '✅ Drinking Water'],
#  ['❌ Maternal Health',
#   '❌ School Attendance',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Maternal Health',
#   '❌ School Attendance',
#   '✅ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Maternal Health',
#   '✅ School Attendance',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Maternal Health',
#   '✅ School Attendance',
#   '✅ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Maternal Health',
#   '✅ Assets',
#   '❌ Drinking Water',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ Maternal Health',
#   '✅ Assets',
#   '❌ Drinking Water',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ Maternal Health',
#   '✅ Assets',
#   '✅ Drinking Water',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ Maternal Health',
#   '✅ Assets',
#   '✅ Drinking Water',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ School Attendance',
#   '✅ Drinking Water',
#   '❌ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ School Attendance',
#   '✅ Drinking Water',
#   '❌ Electricity',
#   '✅ Child & Adolescent Mortality'],
#  ['❌ School Attendance',
#   '✅ Drinking Water',
#   '✅ Electricity',
#   '❌ Child & Adolescent Mortality'],
#  ['❌ School Attendance',
#   '✅ Drinking Water',
#   '✅ Electricity',
#   '✅ Child & Adolescent Mortality']]

# %%
N24_fp = [', '.join(row) for row in N24_fp]
N24_sp = [', '.join(row) for row in N24_sp]

# %%
N24_fp
# Out:
# ['✅ Nutrition, ❌ Years of Schooling, ❌ Cooking Fuel, ❌ Housing',
#  '✅ Nutrition, ❌ Years of Schooling, ❌ Cooking Fuel, ✅ Housing',
#  '✅ Nutrition, ❌ Years of Schooling, ✅ Cooking Fuel, ❌ Housing',
#  '✅ Nutrition, ❌ Years of Schooling, ✅ Cooking Fuel, ✅ Housing',
#  '✅ Nutrition, ❌ Years of Schooling, ❌ Sanitation, ❌ Maternal Health',
#  '✅ Nutrition, ❌ Years of Schooling, ❌ Sanitation, ✅ Maternal Health',
#  '✅ Nutrition, ✅ Years of Schooling, ❌ Sanitation, ❌ Maternal Health',
#  '✅ Nutrition, ✅ Years of Schooling, ❌ Sanitation, ✅ Maternal Health',
#  '❌ Nutrition, ✅ Sanitation, ❌ School Attendance, ❌ Assets',
#  '❌ Nutrition, ✅ Sanitation, ❌ School Attendance, ✅ Assets',
#  '✅ Nutrition, ✅ Sanitation, ❌ School Attendance, ❌ Assets',
#  '✅ Nutrition, ✅ Sanitation, ❌ School Attendance, ✅ Assets',
#  '❌ Nutrition, ❌ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#  '❌ Nutrition, ✅ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#  '✅ Nutrition, ❌ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#  '✅ Nutrition, ✅ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#  '✅ Nutrition, ❌ Years of Schooling, ❌ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Nutrition, ❌ Years of Schooling, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '✅ Nutrition, ❌ Years of Schooling, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Nutrition, ❌ Years of Schooling, ✅ Electricity, ✅ Child & Adolescent Mortality',
#  '✅ Years of Schooling, ❌ Maternal Health, ❌ School Attendance, ❌ Drinking Water',
#  '✅ Years of Schooling, ❌ Maternal Health, ✅ School Attendance, ❌ Drinking Water',
#  '✅ Years of Schooling, ✅ Maternal Health, ❌ School Attendance, ❌ Drinking Water',
#  '✅ Years of Schooling, ✅ Maternal Health, ✅ School Attendance, ❌ Drinking Water',
#  '✅ Cooking Fuel, ❌ Housing, ❌ Sanitation, ❌ Maternal Health',
#  '✅ Cooking Fuel, ❌ Housing, ❌ Sanitation, ✅ Maternal Health',
#  '✅ Cooking Fuel, ❌ Housing, ✅ Sanitation, ❌ Maternal Health',
#  '✅ Cooking Fuel, ❌ Housing, ✅ Sanitation, ✅ Maternal Health',
#  '✅ Cooking Fuel, ❌ Housing, ❌ School Attendance, ❌ Electricity',
#  '✅ Cooking Fuel, ❌ Housing, ✅ School Attendance, ❌ Electricity',
#  '✅ Cooking Fuel, ✅ Housing, ❌ School Attendance, ❌ Electricity',
#  '✅ Cooking Fuel, ✅ Housing, ✅ School Attendance, ❌ Electricity',
#  '✅ Cooking Fuel, ❌ Assets, ❌ Drinking Water, ❌ Electricity',
#  '✅ Cooking Fuel, ❌ Assets, ✅ Drinking Water, ❌ Electricity',
#  '✅ Cooking Fuel, ✅ Assets, ❌ Drinking Water, ❌ Electricity',
#  '✅ Cooking Fuel, ✅ Assets, ✅ Drinking Water, ❌ Electricity',
#  '❌ Cooking Fuel, ❌ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '❌ Cooking Fuel, ✅ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Cooking Fuel, ❌ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Cooking Fuel, ✅ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Housing, ❌ Maternal Health, ❌ Assets, ❌ Child & Adolescent Mortality',
#  '✅ Housing, ❌ Maternal Health, ❌ Assets, ✅ Child & Adolescent Mortality',
#  '✅ Housing, ❌ Maternal Health, ✅ Assets, ❌ Child & Adolescent Mortality',
#  '✅ Housing, ❌ Maternal Health, ✅ Assets, ✅ Child & Adolescent Mortality',
#  '✅ Housing, ❌ Sanitation, ❌ School Attendance, ❌ Drinking Water',
#  '✅ Housing, ❌ Sanitation, ❌ School Attendance, ✅ Drinking Water',
#  '✅ Housing, ❌ Sanitation, ✅ School Attendance, ❌ Drinking Water',
#  '✅ Housing, ❌ Sanitation, ✅ School Attendance, ✅ Drinking Water',
#  '✅ Maternal Health, ❌ School Attendance, ❌ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Maternal Health, ❌ School Attendance, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Maternal Health, ✅ School Attendance, ❌ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Maternal Health, ✅ School Attendance, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ Maternal Health, ❌ Assets, ❌ Drinking Water, ❌ Child & Adolescent Mortality',
#  '✅ Maternal Health, ❌ Assets, ❌ Drinking Water, ✅ Child & Adolescent Mortality',
#  '✅ Maternal Health, ❌ Assets, ✅ Drinking Water, ❌ Child & Adolescent Mortality',
#  '✅ Maternal Health, ❌ Assets, ✅ Drinking Water, ✅ Child & Adolescent Mortality',
#  '✅ School Attendance, ❌ Drinking Water, ❌ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ School Attendance, ❌ Drinking Water, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '✅ School Attendance, ❌ Drinking Water, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '✅ School Attendance, ❌ Drinking Water, ✅ Electricity, ✅ Child & Adolescent Mortality']

# %%
N24_sp
# Out:
# ['❌ Nutrition, ✅ Years of Schooling, ❌ Cooking Fuel, ❌ Housing',
#  '❌ Nutrition, ✅ Years of Schooling, ❌ Cooking Fuel, ✅ Housing',
#  '❌ Nutrition, ✅ Years of Schooling, ✅ Cooking Fuel, ❌ Housing',
#  '❌ Nutrition, ✅ Years of Schooling, ✅ Cooking Fuel, ✅ Housing',
#  '❌ Nutrition, ❌ Years of Schooling, ✅ Sanitation, ❌ Maternal Health',
#  '❌ Nutrition, ❌ Years of Schooling, ✅ Sanitation, ✅ Maternal Health',
#  '❌ Nutrition, ✅ Years of Schooling, ✅ Sanitation, ❌ Maternal Health',
#  '❌ Nutrition, ✅ Years of Schooling, ✅ Sanitation, ✅ Maternal Health',
#  '❌ Nutrition, ❌ Sanitation, ✅ School Attendance, ❌ Assets',
#  '❌ Nutrition, ❌ Sanitation, ✅ School Attendance, ✅ Assets',
#  '✅ Nutrition, ❌ Sanitation, ✅ School Attendance, ❌ Assets',
#  '✅ Nutrition, ❌ Sanitation, ✅ School Attendance, ✅ Assets',
#  '❌ Nutrition, ❌ Years of Schooling, ❌ Assets, ✅ Drinking Water',
#  '❌ Nutrition, ✅ Years of Schooling, ❌ Assets, ✅ Drinking Water',
#  '✅ Nutrition, ❌ Years of Schooling, ❌ Assets, ✅ Drinking Water',
#  '✅ Nutrition, ✅ Years of Schooling, ❌ Assets, ✅ Drinking Water',
#  '❌ Nutrition, ✅ Years of Schooling, ❌ Electricity, ❌ Child & Adolescent Mortality',
#  '❌ Nutrition, ✅ Years of Schooling, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Nutrition, ✅ Years of Schooling, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '❌ Nutrition, ✅ Years of Schooling, ✅ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Years of Schooling, ❌ Maternal Health, ❌ School Attendance, ✅ Drinking Water',
#  '❌ Years of Schooling, ❌ Maternal Health, ✅ School Attendance, ✅ Drinking Water',
#  '❌ Years of Schooling, ✅ Maternal Health, ❌ School Attendance, ✅ Drinking Water',
#  '❌ Years of Schooling, ✅ Maternal Health, ✅ School Attendance, ✅ Drinking Water',
#  '❌ Cooking Fuel, ✅ Housing, ❌ Sanitation, ❌ Maternal Health',
#  '❌ Cooking Fuel, ✅ Housing, ❌ Sanitation, ✅ Maternal Health',
#  '❌ Cooking Fuel, ✅ Housing, ✅ Sanitation, ❌ Maternal Health',
#  '❌ Cooking Fuel, ✅ Housing, ✅ Sanitation, ✅ Maternal Health',
#  '❌ Cooking Fuel, ❌ Housing, ❌ School Attendance, ✅ Electricity',
#  '❌ Cooking Fuel, ❌ Housing, ✅ School Attendance, ✅ Electricity',
#  '❌ Cooking Fuel, ✅ Housing, ❌ School Attendance, ✅ Electricity',
#  '❌ Cooking Fuel, ✅ Housing, ✅ School Attendance, ✅ Electricity',
#  '❌ Cooking Fuel, ❌ Assets, ❌ Drinking Water, ✅ Electricity',
#  '❌ Cooking Fuel, ❌ Assets, ✅ Drinking Water, ✅ Electricity',
#  '❌ Cooking Fuel, ✅ Assets, ❌ Drinking Water, ✅ Electricity',
#  '❌ Cooking Fuel, ✅ Assets, ✅ Drinking Water, ✅ Electricity',
#  '❌ Cooking Fuel, ❌ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Cooking Fuel, ✅ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '✅ Cooking Fuel, ❌ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '✅ Cooking Fuel, ✅ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Housing, ✅ Maternal Health, ❌ Assets, ❌ Child & Adolescent Mortality',
#  '❌ Housing, ✅ Maternal Health, ❌ Assets, ✅ Child & Adolescent Mortality',
#  '❌ Housing, ✅ Maternal Health, ✅ Assets, ❌ Child & Adolescent Mortality',
#  '❌ Housing, ✅ Maternal Health, ✅ Assets, ✅ Child & Adolescent Mortality',
#  '❌ Housing, ✅ Sanitation, ❌ School Attendance, ❌ Drinking Water',
#  '❌ Housing, ✅ Sanitation, ❌ School Attendance, ✅ Drinking Water',
#  '❌ Housing, ✅ Sanitation, ✅ School Attendance, ❌ Drinking Water',
#  '❌ Housing, ✅ Sanitation, ✅ School Attendance, ✅ Drinking Water',
#  '❌ Maternal Health, ❌ School Attendance, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Maternal Health, ❌ School Attendance, ✅ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Maternal Health, ✅ School Attendance, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Maternal Health, ✅ School Attendance, ✅ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ Maternal Health, ✅ Assets, ❌ Drinking Water, ❌ Child & Adolescent Mortality',
#  '❌ Maternal Health, ✅ Assets, ❌ Drinking Water, ✅ Child & Adolescent Mortality',
#  '❌ Maternal Health, ✅ Assets, ✅ Drinking Water, ❌ Child & Adolescent Mortality',
#  '❌ Maternal Health, ✅ Assets, ✅ Drinking Water, ✅ Child & Adolescent Mortality',
#  '❌ School Attendance, ✅ Drinking Water, ❌ Electricity, ❌ Child & Adolescent Mortality',
#  '❌ School Attendance, ✅ Drinking Water, ❌ Electricity, ✅ Child & Adolescent Mortality',
#  '❌ School Attendance, ✅ Drinking Water, ✅ Electricity, ❌ Child & Adolescent Mortality',
#  '❌ School Attendance, ✅ Drinking Water, ✅ Electricity, ✅ Child & Adolescent Mortality']

# %%
N24_CC = list(zip(N24_fp, N24_sp))

# %%
N24_CC
# Out:
# [('✅ Nutrition, ❌ Years of Schooling, ❌ Cooking Fuel, ❌ Housing',
#   '❌ Nutrition, ✅ Years of Schooling, ❌ Cooking Fuel, ❌ Housing'),
#  ('✅ Nutrition, ❌ Years of Schooling, ❌ Cooking Fuel, ✅ Housing',
#   '❌ Nutrition, ✅ Years of Schooling, ❌ Cooking Fuel, ✅ Housing'),
#  ('✅ Nutrition, ❌ Years of Schooling, ✅ Cooking Fuel, ❌ Housing',
#   '❌ Nutrition, ✅ Years of Schooling, ✅ Cooking Fuel, ❌ Housing'),
#  ('✅ Nutrition, ❌ Years of Schooling, ✅ Cooking Fuel, ✅ Housing',
#   '❌ Nutrition, ✅ Years of Schooling, ✅ Cooking Fuel, ✅ Housing'),
#  ('✅ Nutrition, ❌ Years of Schooling, ❌ Sanitation, ❌ Maternal Health',
#   '❌ Nutrition, ❌ Years of Schooling, ✅ Sanitation, ❌ Maternal Health'),
#  ('✅ Nutrition, ❌ Years of Schooling, ❌ Sanitation, ✅ Maternal Health',
#   '❌ Nutrition, ❌ Years of Schooling, ✅ Sanitation, ✅ Maternal Health'),
#  ('✅ Nutrition, ✅ Years of Schooling, ❌ Sanitation, ❌ Maternal Health',
#   '❌ Nutrition, ✅ Years of Schooling, ✅ Sanitation, ❌ Maternal Health'),
#  ('✅ Nutrition, ✅ Years of Schooling, ❌ Sanitation, ✅ Maternal Health',
#   '❌ Nutrition, ✅ Years of Schooling, ✅ Sanitation, ✅ Maternal Health'),
#  ('❌ Nutrition, ✅ Sanitation, ❌ School Attendance, ❌ Assets',
#   '❌ Nutrition, ❌ Sanitation, ✅ School Attendance, ❌ Assets'),
#  ('❌ Nutrition, ✅ Sanitation, ❌ School Attendance, ✅ Assets',
#   '❌ Nutrition, ❌ Sanitation, ✅ School Attendance, ✅ Assets'),
#  ('✅ Nutrition, ✅ Sanitation, ❌ School Attendance, ❌ Assets',
#   '✅ Nutrition, ❌ Sanitation, ✅ School Attendance, ❌ Assets'),
#  ('✅ Nutrition, ✅ Sanitation, ❌ School Attendance, ✅ Assets',
#   '✅ Nutrition, ❌ Sanitation, ✅ School Attendance, ✅ Assets'),
#  ('❌ Nutrition, ❌ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#   '❌ Nutrition, ❌ Years of Schooling, ❌ Assets, ✅ Drinking Water'),
#  ('❌ Nutrition, ✅ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#   '❌ Nutrition, ✅ Years of Schooling, ❌ Assets, ✅ Drinking Water'),
#  ('✅ Nutrition, ❌ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#   '✅ Nutrition, ❌ Years of Schooling, ❌ Assets, ✅ Drinking Water'),
#  ('✅ Nutrition, ✅ Years of Schooling, ✅ Assets, ❌ Drinking Water',
#   '✅ Nutrition, ✅ Years of Schooling, ❌ Assets, ✅ Drinking Water'),
#  ('✅ Nutrition, ❌ Years of Schooling, ❌ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Nutrition, ✅ Years of Schooling, ❌ Electricity, ❌ Child & Adolescent Mortality'),
#  ('✅ Nutrition, ❌ Years of Schooling, ❌ Electricity, ✅ Child & Adolescent Mortality',
#   '❌ Nutrition, ✅ Years of Schooling, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Nutrition, ❌ Years of Schooling, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Nutrition, ✅ Years of Schooling, ✅ Electricity, ❌ Child & Adolescent Mortality'),
#  ('✅ Nutrition, ❌ Years of Schooling, ✅ Electricity, ✅ Child & Adolescent Mortality',
#   '❌ Nutrition, ✅ Years of Schooling, ✅ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Years of Schooling, ❌ Maternal Health, ❌ School Attendance, ❌ Drinking Water',
#   '❌ Years of Schooling, ❌ Maternal Health, ❌ School Attendance, ✅ Drinking Water'),
#  ('✅ Years of Schooling, ❌ Maternal Health, ✅ School Attendance, ❌ Drinking Water',
#   '❌ Years of Schooling, ❌ Maternal Health, ✅ School Attendance, ✅ Drinking Water'),
#  ('✅ Years of Schooling, ✅ Maternal Health, ❌ School Attendance, ❌ Drinking Water',
#   '❌ Years of Schooling, ✅ Maternal Health, ❌ School Attendance, ✅ Drinking Water'),
#  ('✅ Years of Schooling, ✅ Maternal Health, ✅ School Attendance, ❌ Drinking Water',
#   '❌ Years of Schooling, ✅ Maternal Health, ✅ School Attendance, ✅ Drinking Water'),
#  ('✅ Cooking Fuel, ❌ Housing, ❌ Sanitation, ❌ Maternal Health',
#   '❌ Cooking Fuel, ✅ Housing, ❌ Sanitation, ❌ Maternal Health'),
#  ('✅ Cooking Fuel, ❌ Housing, ❌ Sanitation, ✅ Maternal Health',
#   '❌ Cooking Fuel, ✅ Housing, ❌ Sanitation, ✅ Maternal Health'),
#  ('✅ Cooking Fuel, ❌ Housing, ✅ Sanitation, ❌ Maternal Health',
#   '❌ Cooking Fuel, ✅ Housing, ✅ Sanitation, ❌ Maternal Health'),
#  ('✅ Cooking Fuel, ❌ Housing, ✅ Sanitation, ✅ Maternal Health',
#   '❌ Cooking Fuel, ✅ Housing, ✅ Sanitation, ✅ Maternal Health'),
#  ('✅ Cooking Fuel, ❌ Housing, ❌ School Attendance, ❌ Electricity',
#   '❌ Cooking Fuel, ❌ Housing, ❌ School Attendance, ✅ Electricity'),
#  ('✅ Cooking Fuel, ❌ Housing, ✅ School Attendance, ❌ Electricity',
#   '❌ Cooking Fuel, ❌ Housing, ✅ School Attendance, ✅ Electricity'),
#  ('✅ Cooking Fuel, ✅ Housing, ❌ School Attendance, ❌ Electricity',
#   '❌ Cooking Fuel, ✅ Housing, ❌ School Attendance, ✅ Electricity'),
#  ('✅ Cooking Fuel, ✅ Housing, ✅ School Attendance, ❌ Electricity',
#   '❌ Cooking Fuel, ✅ Housing, ✅ School Attendance, ✅ Electricity'),
#  ('✅ Cooking Fuel, ❌ Assets, ❌ Drinking Water, ❌ Electricity',
#   '❌ Cooking Fuel, ❌ Assets, ❌ Drinking Water, ✅ Electricity'),
#  ('✅ Cooking Fuel, ❌ Assets, ✅ Drinking Water, ❌ Electricity',
#   '❌ Cooking Fuel, ❌ Assets, ✅ Drinking Water, ✅ Electricity'),
#  ('✅ Cooking Fuel, ✅ Assets, ❌ Drinking Water, ❌ Electricity',
#   '❌ Cooking Fuel, ✅ Assets, ❌ Drinking Water, ✅ Electricity'),
#  ('✅ Cooking Fuel, ✅ Assets, ✅ Drinking Water, ❌ Electricity',
#   '❌ Cooking Fuel, ✅ Assets, ✅ Drinking Water, ✅ Electricity'),
#  ('❌ Cooking Fuel, ❌ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Cooking Fuel, ❌ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('❌ Cooking Fuel, ✅ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Cooking Fuel, ✅ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Cooking Fuel, ❌ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '✅ Cooking Fuel, ❌ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Cooking Fuel, ✅ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '✅ Cooking Fuel, ✅ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Housing, ❌ Maternal Health, ❌ Assets, ❌ Child & Adolescent Mortality',
#   '❌ Housing, ✅ Maternal Health, ❌ Assets, ❌ Child & Adolescent Mortality'),
#  ('✅ Housing, ❌ Maternal Health, ❌ Assets, ✅ Child & Adolescent Mortality',
#   '❌ Housing, ✅ Maternal Health, ❌ Assets, ✅ Child & Adolescent Mortality'),
#  ('✅ Housing, ❌ Maternal Health, ✅ Assets, ❌ Child & Adolescent Mortality',
#   '❌ Housing, ✅ Maternal Health, ✅ Assets, ❌ Child & Adolescent Mortality'),
#  ('✅ Housing, ❌ Maternal Health, ✅ Assets, ✅ Child & Adolescent Mortality',
#   '❌ Housing, ✅ Maternal Health, ✅ Assets, ✅ Child & Adolescent Mortality'),
#  ('✅ Housing, ❌ Sanitation, ❌ School Attendance, ❌ Drinking Water',
#   '❌ Housing, ✅ Sanitation, ❌ School Attendance, ❌ Drinking Water'),
#  ('✅ Housing, ❌ Sanitation, ❌ School Attendance, ✅ Drinking Water',
#   '❌ Housing, ✅ Sanitation, ❌ School Attendance, ✅ Drinking Water'),
#  ('✅ Housing, ❌ Sanitation, ✅ School Attendance, ❌ Drinking Water',
#   '❌ Housing, ✅ Sanitation, ✅ School Attendance, ❌ Drinking Water'),
#  ('✅ Housing, ❌ Sanitation, ✅ School Attendance, ✅ Drinking Water',
#   '❌ Housing, ✅ Sanitation, ✅ School Attendance, ✅ Drinking Water'),
#  ('✅ Maternal Health, ❌ School Attendance, ❌ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Maternal Health, ❌ School Attendance, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Maternal Health, ❌ School Attendance, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Maternal Health, ❌ School Attendance, ✅ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Maternal Health, ✅ School Attendance, ❌ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Maternal Health, ✅ School Attendance, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Maternal Health, ✅ School Attendance, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ Maternal Health, ✅ School Attendance, ✅ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ Maternal Health, ❌ Assets, ❌ Drinking Water, ❌ Child & Adolescent Mortality',
#   '❌ Maternal Health, ✅ Assets, ❌ Drinking Water, ❌ Child & Adolescent Mortality'),
#  ('✅ Maternal Health, ❌ Assets, ❌ Drinking Water, ✅ Child & Adolescent Mortality',
#   '❌ Maternal Health, ✅ Assets, ❌ Drinking Water, ✅ Child & Adolescent Mortality'),
#  ('✅ Maternal Health, ❌ Assets, ✅ Drinking Water, ❌ Child & Adolescent Mortality',
#   '❌ Maternal Health, ✅ Assets, ✅ Drinking Water, ❌ Child & Adolescent Mortality'),
#  ('✅ Maternal Health, ❌ Assets, ✅ Drinking Water, ✅ Child & Adolescent Mortality',
#   '❌ Maternal Health, ✅ Assets, ✅ Drinking Water, ✅ Child & Adolescent Mortality'),
#  ('✅ School Attendance, ❌ Drinking Water, ❌ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ School Attendance, ✅ Drinking Water, ❌ Electricity, ❌ Child & Adolescent Mortality'),
#  ('✅ School Attendance, ❌ Drinking Water, ❌ Electricity, ✅ Child & Adolescent Mortality',
#   '❌ School Attendance, ✅ Drinking Water, ❌ Electricity, ✅ Child & Adolescent Mortality'),
#  ('✅ School Attendance, ❌ Drinking Water, ✅ Electricity, ❌ Child & Adolescent Mortality',
#   '❌ School Attendance, ✅ Drinking Water, ✅ Electricity, ❌ Child & Adolescent Mortality'),
#  ('✅ School Attendance, ❌ Drinking Water, ✅ Electricity, ✅ Child & Adolescent Mortality',
#   '❌ School Attendance, ✅ Drinking Water, ✅ Electricity, ✅ Child & Adolescent Mortality')]

# %%
N24_CC_fin = ['\n'.join(row) for row in N24_CC]

# %%
print(N24_CC_fin[0])
# Out:
# ✅ Nutrition, ❌ Years of Schooling, ❌ Cooking Fuel, ❌ Housing
# ❌ Nutrition, ✅ Years of Schooling, ❌ Cooking Fuel, ❌ Housing

# %%
print(f'Number of people who will span the entire choice sets i.e. 60 is {len(N24_CC_fin)//12}')
# Out:
# Number of people who will span the entire choice sets i.e. 60 is 5

# %%
for i in range(5):
  print()
  print('***********')
  print(f'Candidate {i+1}')
  print('***********')
  print()
  questions_to_ask = N24_CC_fin[i::5].copy()
  random.shuffle(questions_to_ask)
  for qsn_no, question in enumerate(questions_to_ask):
    print()
    print(f'Question-{qsn_no+1}:')
    print(question)
# Out:
# ***********
# Candidate 1
# ***********
#
#
# Question-1:
# ✅ Housing, ❌ Sanitation, ❌ School Attendance, ✅ Drinking Water
# ❌ Housing, ✅ Sanitation, ❌ School Attendance, ✅ Drinking Water
#
# Question-2:
# ✅ Cooking Fuel, ✅ Assets, ✅ Drinking Water, ❌ Electricity
# ❌ Cooking Fuel, ✅ Assets, ✅ Drinking Water, ✅ Electricity
#
# Question-3:
# ✅ Housing, ❌ Maternal Health, ❌ Assets, ❌ Child & Adolescent Mortality
# ❌ Housing, ✅ Maternal Health, ❌ Assets, ❌ Child & Adolescent Mortality
#
# Question-4:
# ✅ Cooking Fuel, ❌ Housing, ❌ Sanitation, ✅ Maternal Health
# ❌ Cooking Fuel, ✅ Housing, ❌ Sanitation, ✅ Maternal Health
#
# Question-5:
# ✅ Years of Schooling, ❌ Maternal Health, ❌ School Attendance, ❌ Drinking Water
# ❌ Years of Schooling, ❌ Maternal Health, ❌ School Attendance, ✅ Drinking Water
#
# Question-6:
# ✅ Maternal Health, ✅ School Attendance, ❌ Electricity, ❌ Child & Adolescent Mortality
# ❌ Maternal Health, ✅ School Attendance, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# Question-7:
# ✅ Maternal Health, ❌ Assets, ✅ Drinking Water, ✅ Child & Adolescent Mortality
# ❌ Maternal Health, ✅ Assets, ✅ Drinking Water, ✅ Child & Adolescent Mortality
#
# Question-8:
# ✅ Cooking Fuel, ✅ Housing, ❌ School Attendance, ❌ Electricity
# ❌ Cooking Fuel, ✅ Housing, ❌ School Attendance, ✅ Electricity
#
# Question-9:
# ✅ Nutrition, ✅ Years of Schooling, ✅ Assets, ❌ Drinking Water
# ✅ Nutrition, ✅ Years of Schooling, ❌ Assets, ✅ Drinking Water
#
# Question-10:
# ✅ Nutrition, ❌ Years of Schooling, ❌ Cooking Fuel, ❌ Housing
# ❌ Nutrition, ✅ Years of Schooling, ❌ Cooking Fuel, ❌ Housing
#
# Question-11:
# ✅ Nutrition, ❌ Years of Schooling, ❌ Sanitation, ✅ Maternal Health
# ❌ Nutrition, ❌ Years of Schooling, ✅ Sanitation, ✅ Maternal Health
#
# Question-12:
# ✅ Nutrition, ✅ Sanitation, ❌ School Attendance, ❌ Assets
# ✅ Nutrition, ❌ Sanitation, ✅ School Attendance, ❌ Assets
#
# ***********
# Candidate 2
# ***********
#
#
# Question-1:
# ✅ Maternal Health, ✅ School Attendance, ✅ Electricity, ❌ Child & Adolescent Mortality
# ❌ Maternal Health, ✅ School Attendance, ✅ Electricity, ✅ Child & Adolescent Mortality
#
# Question-2:
# ✅ Nutrition, ❌ Years of Schooling, ❌ Cooking Fuel, ✅ Housing
# ❌ Nutrition, ✅ Years of Schooling, ❌ Cooking Fuel, ✅ Housing
#
# Question-3:
# ✅ Nutrition, ❌ Years of Schooling, ❌ Electricity, ❌ Child & Adolescent Mortality
# ❌ Nutrition, ✅ Years of Schooling, ❌ Electricity, ❌ Child & Adolescent Mortality
#
# Question-4:
# ✅ Housing, ❌ Sanitation, ✅ School Attendance, ❌ Drinking Water
# ❌ Housing, ✅ Sanitation, ✅ School Attendance, ❌ Drinking Water
#
# Question-5:
# ✅ School Attendance, ❌ Drinking Water, ❌ Electricity, ❌ Child & Adolescent Mortality
# ❌ School Attendance, ✅ Drinking Water, ❌ Electricity, ❌ Child & Adolescent Mortality
#
# Question-6:
# ✅ Nutrition, ✅ Sanitation, ❌ School Attendance, ✅ Assets
# ✅ Nutrition, ❌ Sanitation, ✅ School Attendance, ✅ Assets
#
# Question-7:
# ❌ Cooking Fuel, ❌ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality
# ❌ Cooking Fuel, ❌ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# Question-8:
# ✅ Cooking Fuel, ✅ Housing, ✅ School Attendance, ❌ Electricity
# ❌ Cooking Fuel, ✅ Housing, ✅ School Attendance, ✅ Electricity
#
# Question-9:
# ✅ Housing, ❌ Maternal Health, ❌ Assets, ✅ Child & Adolescent Mortality
# ❌ Housing, ✅ Maternal Health, ❌ Assets, ✅ Child & Adolescent Mortality
#
# Question-10:
# ✅ Years of Schooling, ❌ Maternal Health, ✅ School Attendance, ❌ Drinking Water
# ❌ Years of Schooling, ❌ Maternal Health, ✅ School Attendance, ✅ Drinking Water
#
# Question-11:
# ✅ Nutrition, ✅ Years of Schooling, ❌ Sanitation, ❌ Maternal Health
# ❌ Nutrition, ✅ Years of Schooling, ✅ Sanitation, ❌ Maternal Health
#
# Question-12:
# ✅ Cooking Fuel, ❌ Housing, ✅ Sanitation, ❌ Maternal Health
# ❌ Cooking Fuel, ✅ Housing, ✅ Sanitation, ❌ Maternal Health
#
# ***********
# Candidate 3
# ***********
#
#
# Question-1:
# ❌ Nutrition, ❌ Years of Schooling, ✅ Assets, ❌ Drinking Water
# ❌ Nutrition, ❌ Years of Schooling, ❌ Assets, ✅ Drinking Water
#
# Question-2:
# ✅ Housing, ❌ Maternal Health, ✅ Assets, ❌ Child & Adolescent Mortality
# ❌ Housing, ✅ Maternal Health, ✅ Assets, ❌ Child & Adolescent Mortality
#
# Question-3:
# ✅ Cooking Fuel, ❌ Assets, ❌ Drinking Water, ❌ Electricity
# ❌ Cooking Fuel, ❌ Assets, ❌ Drinking Water, ✅ Electricity
#
# Question-4:
# ✅ Maternal Health, ❌ Assets, ❌ Drinking Water, ❌ Child & Adolescent Mortality
# ❌ Maternal Health, ✅ Assets, ❌ Drinking Water, ❌ Child & Adolescent Mortality
#
# Question-5:
# ✅ Nutrition, ❌ Years of Schooling, ✅ Cooking Fuel, ❌ Housing
# ❌ Nutrition, ✅ Years of Schooling, ✅ Cooking Fuel, ❌ Housing
#
# Question-6:
# ❌ Cooking Fuel, ✅ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality
# ❌ Cooking Fuel, ✅ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# Question-7:
# ✅ School Attendance, ❌ Drinking Water, ❌ Electricity, ✅ Child & Adolescent Mortality
# ❌ School Attendance, ✅ Drinking Water, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# Question-8:
# ✅ Cooking Fuel, ❌ Housing, ✅ Sanitation, ✅ Maternal Health
# ❌ Cooking Fuel, ✅ Housing, ✅ Sanitation, ✅ Maternal Health
#
# Question-9:
# ✅ Years of Schooling, ✅ Maternal Health, ❌ School Attendance, ❌ Drinking Water
# ❌ Years of Schooling, ✅ Maternal Health, ❌ School Attendance, ✅ Drinking Water
#
# Question-10:
# ✅ Nutrition, ❌ Years of Schooling, ❌ Electricity, ✅ Child & Adolescent Mortality
# ❌ Nutrition, ✅ Years of Schooling, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# Question-11:
# ✅ Housing, ❌ Sanitation, ✅ School Attendance, ✅ Drinking Water
# ❌ Housing, ✅ Sanitation, ✅ School Attendance, ✅ Drinking Water
#
# Question-12:
# ✅ Nutrition, ✅ Years of Schooling, ❌ Sanitation, ✅ Maternal Health
# ❌ Nutrition, ✅ Years of Schooling, ✅ Sanitation, ✅ Maternal Health
#
# ***********
# Candidate 4
# ***********
#
#
# Question-1:
# ❌ Nutrition, ✅ Sanitation, ❌ School Attendance, ❌ Assets
# ❌ Nutrition, ❌ Sanitation, ✅ School Attendance, ❌ Assets
#
# Question-2:
# ✅ Maternal Health, ❌ Assets, ❌ Drinking Water, ✅ Child & Adolescent Mortality
# ❌ Maternal Health, ✅ Assets, ❌ Drinking Water, ✅ Child & Adolescent Mortality
#
# Question-3:
# ✅ Cooking Fuel, ❌ Housing, ❌ School Attendance, ❌ Electricity
# ❌ Cooking Fuel, ❌ Housing, ❌ School Attendance, ✅ Electricity
#
# Question-4:
# ✅ Maternal Health, ❌ School Attendance, ❌ Electricity, ❌ Child & Adolescent Mortality
# ❌ Maternal Health, ❌ School Attendance, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# Question-5:
# ✅ Cooking Fuel, ❌ Assets, ✅ Drinking Water, ❌ Electricity
# ❌ Cooking Fuel, ❌ Assets, ✅ Drinking Water, ✅ Electricity
#
# Question-6:
# ✅ Housing, ❌ Maternal Health, ✅ Assets, ✅ Child & Adolescent Mortality
# ❌ Housing, ✅ Maternal Health, ✅ Assets, ✅ Child & Adolescent Mortality
#
# Question-7:
# ✅ Nutrition, ❌ Years of Schooling, ✅ Electricity, ❌ Child & Adolescent Mortality
# ❌ Nutrition, ✅ Years of Schooling, ✅ Electricity, ❌ Child & Adolescent Mortality
#
# Question-8:
# ❌ Nutrition, ✅ Years of Schooling, ✅ Assets, ❌ Drinking Water
# ❌ Nutrition, ✅ Years of Schooling, ❌ Assets, ✅ Drinking Water
#
# Question-9:
# ✅ Nutrition, ❌ Years of Schooling, ✅ Cooking Fuel, ✅ Housing
# ❌ Nutrition, ✅ Years of Schooling, ✅ Cooking Fuel, ✅ Housing
#
# Question-10:
# ✅ Years of Schooling, ✅ Maternal Health, ✅ School Attendance, ❌ Drinking Water
# ❌ Years of Schooling, ✅ Maternal Health, ✅ School Attendance, ✅ Drinking Water
#
# Question-11:
# ✅ School Attendance, ❌ Drinking Water, ✅ Electricity, ❌ Child & Adolescent Mortality
# ❌ School Attendance, ✅ Drinking Water, ✅ Electricity, ❌ Child & Adolescent Mortality
#
# Question-12:
# ✅ Cooking Fuel, ❌ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality
# ✅ Cooking Fuel, ❌ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# ***********
# Candidate 5
# ***********
#
#
# Question-1:
# ✅ Nutrition, ❌ Years of Schooling, ❌ Sanitation, ❌ Maternal Health
# ❌ Nutrition, ❌ Years of Schooling, ✅ Sanitation, ❌ Maternal Health
#
# Question-2:
# ✅ Housing, ❌ Sanitation, ❌ School Attendance, ❌ Drinking Water
# ❌ Housing, ✅ Sanitation, ❌ School Attendance, ❌ Drinking Water
#
# Question-3:
# ✅ Cooking Fuel, ❌ Housing, ❌ Sanitation, ❌ Maternal Health
# ❌ Cooking Fuel, ✅ Housing, ❌ Sanitation, ❌ Maternal Health
#
# Question-4:
# ✅ School Attendance, ❌ Drinking Water, ✅ Electricity, ✅ Child & Adolescent Mortality
# ❌ School Attendance, ✅ Drinking Water, ✅ Electricity, ✅ Child & Adolescent Mortality
#
# Question-5:
# ✅ Nutrition, ❌ Years of Schooling, ✅ Electricity, ✅ Child & Adolescent Mortality
# ❌ Nutrition, ✅ Years of Schooling, ✅ Electricity, ✅ Child & Adolescent Mortality
#
# Question-6:
# ✅ Maternal Health, ❌ School Attendance, ✅ Electricity, ❌ Child & Adolescent Mortality
# ❌ Maternal Health, ❌ School Attendance, ✅ Electricity, ✅ Child & Adolescent Mortality
#
# Question-7:
# ✅ Cooking Fuel, ❌ Housing, ✅ School Attendance, ❌ Electricity
# ❌ Cooking Fuel, ❌ Housing, ✅ School Attendance, ✅ Electricity
#
# Question-8:
# ✅ Nutrition, ❌ Years of Schooling, ✅ Assets, ❌ Drinking Water
# ✅ Nutrition, ❌ Years of Schooling, ❌ Assets, ✅ Drinking Water
#
# Question-9:
# ✅ Cooking Fuel, ✅ Sanitation, ✅ Electricity, ❌ Child & Adolescent Mortality
# ✅ Cooking Fuel, ✅ Sanitation, ❌ Electricity, ✅ Child & Adolescent Mortality
#
# Question-10:
# ✅ Cooking Fuel, ✅ Assets, ❌ Drinking Water, ❌ Electricity
# ❌ Cooking Fuel, ✅ Assets, ❌ Drinking Water, ✅ Electricity
#
# Question-11:
# ✅ Maternal Health, ❌ Assets, ✅ Drinking Water, ❌ Child & Adolescent Mortality
# ❌ Maternal Health, ✅ Assets, ✅ Drinking Water, ❌ Child & Adolescent Mortality
#
# Question-12:
# ❌ Nutrition, ✅ Sanitation, ❌ School Attendance, ✅ Assets
# ❌ Nutrition, ❌ Sanitation, ✅ School Attendance, ✅ Assets

# %%
for i in range(5):
  print(f'The questions asked to Candidate-{i+1}') # shuffled
  print(list(range(1,61))[i::5])
  print()
# Out:
# The questions asked to Candidate-1
# [1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56]
#
# The questions asked to Candidate-2
# [2, 7, 12, 17, 22, 27, 32, 37, 42, 47, 52, 57]
#
# The questions asked to Candidate-3
# [3, 8, 13, 18, 23, 28, 33, 38, 43, 48, 53, 58]
#
# The questions asked to Candidate-4
# [4, 9, 14, 19, 24, 29, 34, 39, 44, 49, 54, 59]
#
# The questions asked to Candidate-5
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60]
